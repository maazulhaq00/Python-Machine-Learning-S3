# %%
# !pip install pandas numpy matplotlib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# from sklearn.linear_model import LinearRegression

# %% [markdown]
# \\server1\Faculty Data\Maaz Ul Haq\AI Primer\datasets\lectures

# %%
df = pd.read_csv('homeprices1.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model = linear_model.LinearRegression()
# model = LinearRegression()

# %%
model.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
model.predict([[3300]])
# Out:
# C:\Users\maazulhaq\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# y = mx + c
# price = 135.78767123*area + 180616.43835616432

135.78767123*3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area, df.price, color="red", marker="+")

# %%
df_areas = pd.read_csv("areas.csv")
df_areas.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  3200
# 3  4600
# 4  5700

# %%
model.predict([[3300], [2200]])
# Out:
# C:\Users\maazulhaq\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466, 479349.31506849])

# %%
pred_prices = model.predict(df_areas[["area"]])
pred_prices
# Out:
# array([ 316404.10958904,  384297.94520548,  615136.98630137,
#         805239.7260274 ,  954606.16438356, 1124340.75342466,
#        1294075.34246575, 1463809.93150685, 1633544.52054795])

# %%
df_areas["price_p"] = pred_prices
df_areas.head()
# Out:
#    area        price_p
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  3200  615136.986301
# 3  4600  805239.726027
# 4  5700  954606.164384

# %%
df_areas.to_csv("prediction.csv", index=False)

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area, df.price, color="red", marker="+")
plt.scatter(df_areas.area, df_areas.price_p, color="black", marker="+")
